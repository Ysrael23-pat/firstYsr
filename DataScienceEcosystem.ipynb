# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## **Objetives**
# * Use lenguages commonly used by data scientists, such as Python, R, and SQL
# * Identify and describe programming languages
# * Describe the data scientist´s toolkint

# %% [markdown]
# ## Some of the popular languages that Data Scientists use are:
# ### R
# ### Python
# ### SQL
# ### Scala

# %% [markdown]
# ## Some of the commonly used libraries used by Data Scientists include:
# ### Python
# #### Numpy
# #### Pandas
# #### Matplotlib
# ### R
# #### dplyr
# #### ggplot

# %% [markdown]
# |Data Sciencie Tools|
# |-------------------|
# |Jupyter Notebooks|
# |RStudio|
# |Visual Studio Code|

# %% [markdown]
# ### A continuación se muestran algunos ejemplos de evaluación de expresiones aritméticas en Python.

# %% [markdown]
# # This a simple arithmetic expression to mutiply then add integers"

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ## This will convert 200 minutes to hours by diving by 60

# %%
minutos = 200
horas = minutos / 60
print(f"{minutos} minutos son {horas} horas.")
# Out:
# 200 minutos son 3.3333333333333335 horas.

# %% [markdown]
# ## Author
# ### Ysrael Lopez Patiño
